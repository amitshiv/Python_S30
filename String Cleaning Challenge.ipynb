# %%
student = "python programming for data science"

# %%
print(student)
# Out:
# python programming for data science

# %%
student[0]
# Out:
# 'p'

# %%
student[-1]
# Out:
# 'e'

# %%
student[0:6]
# Out:
# 'python'

# %%
student[0:5]
# Out:
# 'pytho'

# %%
student
# Out:
# 'python programming for data science'

# %%
student[-7:]
# Out:
# 'science'

# %%
student[::-1]
# Out:
# 'ecneics atad rof gnimmargorp nohtyp'

# %%
student
# Out:
# 'python programming for data science'

# %%
student.upper()
# Out:
# 'PYTHON PROGRAMMING FOR DATA SCIENCE'

# %%
student.lower()
# Out:
# 'python programming for data science'

# %%
student.title()
# Out:
# 'Python Programming For Data Science'

# %%
student.count("a")
# Out:
# 3

# %%
student.find("programming")
# Out:
# 7

# %%
student.replace("data science", "AI")
# Out:
# 'python programming for AI'

# %%
student
# Out:
# 'python programming for data science'

# %%
student.split()
# Out:
# ['python', 'programming', 'for', 'data', 'science']
