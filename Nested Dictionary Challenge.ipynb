# %%
emp = {
    "name":"amit","department":"Engineering","skill":
    {"language":"Python","database":"SQL","cloud":"aws"}
    ,"salary":80000}

# %%
emp["name"]
# Out:
# 'amit'

# %%
emp["department"]
# Out:
# 'Engineering'

# %%
emp["skill"]
# Out:
# {'languge': 'Python', 'database': 'SQL', 'cloud': 'aws'}

# %%
emp
# Out:
# {'name': 'amit',
#  'department': 'Engineering',
#  'skill': {'language': 'Python', 'database': 'SQL', 'cloud': 'aws'},
#  'salary': 80000}

# %%
emp["skill"]["language"]
# Out:
# 'Python'

# %%
print(emp["skill"]["language"])
# Out:
# Python

# %%
print(emp["skill"]["database"])
# Out:
# SQL

# %%
print(emp["skill"]["cloud"])
# Out:
# aws

# %%
emp["skill"]["language"]= "Python+javascript"

# %%
emp
# Out:
# {'name': 'amit',
#  'department': 'Engineering',
#  'skill': {'language': 'Python+javascript', 'database': 'SQL', 'cloud': 'aws'},
#  'salary': 80000}

# %%
emp["salary"]= 90000

# %%
emp
# Out:
# {'name': 'amit',
#  'department': 'Engineering',
#  'skill': {'language': 'Python+javascript', 'database': 'SQL', 'cloud': 'aws'},
#  'salary': 90000}

# %%
emp["exp"] = 5

# %%
emp
# Out:
# {'name': 'amit',
#  'department': 'Engineering',
#  'skill': {'language': 'Python+javascript', 'database': 'SQL', 'cloud': 'aws'},
#  'salary': 90000,
#  'exp': 5}

# %%
emp["skill"]["tool"] = "docker"

# %%
emp
# Out:
# {'name': 'amit',
#  'department': 'Engineering',
#  'skill': {'language': 'Python+javascript',
#   'database': 'SQL',
#   'cloud': 'aws',
#   'tool': 'docker'},
#  'salary': 90000,
#  'exp': 5}
