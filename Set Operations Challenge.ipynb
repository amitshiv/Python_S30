# %%
Python

# %%
Java

# %%
python_students = { "Rahul","Aman","Priya","Karan","Neha"}

# %%
java_students = {"Priya","Karan","Rohit","Simran"}

# %%
print(python_students)
print(java_students)
# Out:
# {'Rahul', 'Priya', 'Neha', 'Karan', 'Aman'}
# {'Rohit', 'Karan', 'Priya', 'Simran'}

# %%
both_course = python_students.union(java_students)

# %%
both_course
# Out:
# {'Aman', 'Karan', 'Neha', 'Priya', 'Rahul', 'Rohit', 'Simran'}

# %%
#who is learning both courses

# %%
both_student = python_students.intersection(java_students)

# %%
print(both_student)
# Out:
# {'Karan', 'Priya'}

# %%
#Only Python not java

# %%
only_python = python_students.difference(java_students)

# %%
print(only_python)
# Out:
# {'Rahul', 'Aman', 'Neha'}

# %%
#Only Java not python

# %%
only_java = java_students.difference(python_students)

# %%
print(only_java)
# Out:
# {'Rohit', 'Simran'}

# %%
one_group = python_students.symmetric_difference(java_students)

# %%
print(one_group)
# Out:
# {'Simran', 'Aman', 'Rahul', 'Neha', 'Rohit'}

# %%
#anjali wants to join Python class

# %%
python_students.add("anjali")

# %%
python_students
# Out:
# {'Aman', 'Karan', 'Neha', 'Priya', 'Rahul', 'anjali'}

# %%
python_students.remove("Karan")

# %%
python_students
# Out:
# {'Aman', 'Neha', 'Priya', 'Rahul', 'anjali'}

# %%
python_students.remove("Amit")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 python_students.remove("Amit")
#
# KeyError: 'Amit'

# %%
#discard

# %%
python_students.discard("Amit")

# %%
python_students
# Out:
# {'Aman', 'Neha', 'Priya', 'Rahul', 'anjali'}
