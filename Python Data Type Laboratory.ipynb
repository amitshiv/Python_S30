# %%
x= 100
y= "100"
z= 100.0

# %%
#intergers

# %%
students = 40
marks = 88

# %%
type(students)
# Out:
# int

# %%
price = 45.67

# %%
type(price)
# Out:
# float

# %%
#string

# %%
name ="Amit"

# %%
type(name)
# Out:
# str

# %%
x =100
y = "100"

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# str

# %%
# True  False

# %%
is_logges_in = True

# %%
is_raining = False

# %%
type(is_logges_in)
# Out:
# bool

# %%
fruits = ["Apple" , "banana", "Mango"]

# %%
type(fruits)
# Out:
# list

# %%
fruits2 = ("apple", "banana")

# %%
type(fruits2)
# Out:
# tuple

# %%
number = {1,2,3,3,4}

# %%
number
# Out:
# {1, 2, 3, 4}

# %%
#dictionary

# %%
students = { "name":"Amit", "course":"Python"

}

# %%
type(students)
# Out:
# dict

# %%
age = 28
students= 40
marks = 88

price = 45.67
hieght = 5.8
temprature = 36.5

name = "Amit"
course = "python"
message = "Welcome to Python"

is_actuve = True
is_logges_in = False

fruits = ["Apple", "banana", "Mango"]
numbers = [10, 20,30]

coordinates = (10,20)

unique_numbers= {1,2,3,4,5,5}
languages ={"Python","Java","C++"}

students = {"name ":"Amit", "course":"Python"}

# %%
type(age)
# Out:
# int

# %%
type(price)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
type(is_actuve)
# Out:
# bool

# %%
type(fruits)
# Out:
# list

# %%
type(coordinates)
# Out:
# tuple

# %%
type(unique_numbers)
# Out:
# set

# %%
type(students)
# Out:
# dict

# %%
x = int("100")

# %%
type(x)
# Out:
# int

# %%
x = float("45.67")

# %%
type(x)
# Out:
# float

# %%
x = str(500)

# %%
type(x)
# Out:
# str

# %%
#int to bool

# %%
x = bool(1)

# %%
type(x)
# Out:
# bool

# %%
#tuple to list

# %%
x =list((1,2,3))

# %%
type(x)
# Out:
# list

# %%
x
# Out:
# [1, 2, 3]

# %%
#list to Tuple

# %%
x = tuple([1,2,3])

# %%
print(x)
# Out:
# (1, 2, 3)

# %%
type(x)
# Out:
# tuple

# %%
#list to set

# %%
x= set([1,2,3,4,5,5])

# %%
type(x)
# Out:
# set

# %%
x
# Out:
# {1, 2, 3, 4, 5}
