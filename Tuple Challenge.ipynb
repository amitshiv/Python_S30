# %%
technologies = ("Python","Java","Python","C++","javascript","Python")

# %%
print(technologies)
# Out:
# ('Python', 'Java', 'Python', 'C++', 'javascript', 'Python')

# %%
type(technologies)
# Out:
# tuple

# %%
technologies[1]
# Out:
# 'Java'

# %%
technologies[-2]
# Out:
# 'javascript'

# %%
technologies
# Out:
# ('Python', 'Java', 'Python', 'C++', 'javascript', 'Python')

# %%
technologies[1:4]
# Out:
# ('Java', 'Python', 'C++')

# %%
technologies.count("Python")
# Out:
# 3

# %%
technologies.index("C++")
# Out:
# 3

# %%
len(technologies)
# Out:
# 6

# %%
technologies
# Out:
# ('Python', 'Java', 'Python', 'C++', 'javascript', 'Python')

# %%
technologies.append("Go")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 technologies.append("Go")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
technologies[0] = "Rust"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 technologies[0] = "Rust"
#
# TypeError: 'tuple' object does not support item assignment

# %%
technologies
# Out:
# ('Python', 'Java', 'Python', 'C++', 'javascript', 'Python')

# %%
new_technologies = list(technologies)

# %%
new_technologies
# Out:
# ['Python', 'Java', 'Python', 'C++', 'javascript', 'Python']

# %%
type(new_technologies)
# Out:
# list

# %%
new_technologies.append("go")

# %%
new_technologies
# Out:
# ['Python', 'Java', 'Python', 'C++', 'javascript', 'Python', 'go']

# %%
technologies = tuple(new_technologies)

# %%
type(technologies)
# Out:
# tuple

# %%
technologies
# Out:
# ('Python', 'Java', 'Python', 'C++', 'javascript', 'Python', 'go')
