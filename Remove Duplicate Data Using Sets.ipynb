# %%
ls = [10,20,30,20,40,10,50,60]

# %%
print(ls)
# Out:
# [10, 20, 30, 20, 40, 10, 50, 60]

# %%
#total elements

# %%
#unique elemts

# %%
number_set = set(ls)

# %%
print(number_set)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
unique_number = list(number_set)

# %%
type(unique_number)
# Out:
# list

# %%
print(len(ls))
# Out:
# 8

# %%
print(len(number_set))
# Out:
# 6

# %%
vistor = [101,102,103,104,101,102,105]

# %%
len(vistor)
# Out:
# 7

# %%
unique_vistor= set(vistor)

# %%
len(unique_vistor)
# Out:
# 5

# %%
student = ["Rahul","Priya","Rahul","Neha","aman","Priya"]

# %%
print(student)
print(len(student))
# Out:
# ['Rahul', 'Priya', 'Rahul', 'Neha', 'aman', 'Priya']
# 6

# %%
new_student = set(student)

# %%
print(new_student)
print(len(new_student))
# Out:
# {'Priya', 'aman', 'Rahul', 'Neha'}
# 4
