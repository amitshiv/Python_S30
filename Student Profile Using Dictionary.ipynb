# %%
student = { "name":"Rahul", 
"age":22 , "course":"Python", "city":"banglore","marks":88

}

# %%
print(student)
# Out:
# {'name': 'Rahul', 'age': 22, 'course': 'Python', 'city': 'banglore', 'marks': 88}

# %%
#Only Rahul's name

print(student["name"])
# Out:
# Rahul

# %%
#Only course

print(student["course"])
# Out:
# Python

# %%
#only keys

print(student.keys())
# Out:
# dict_keys(['name', 'age', 'course', 'city', 'marks'])

# %%
#only vlaues
print(student.values())
# Out:
# dict_values(['Rahul', 22, 'Python', 'banglore', 88])

# %%
#Both Information

print(student.items())
# Out:
# dict_items([('name', 'Rahul'), ('age', 22), ('course', 'Python'), ('city', 'banglore'), ('marks', 88)])

# %%
#update marks

student["marks"] = 92

# %%
student
# Out:
# {'name': 'Rahul',
#  'age': 22,
#  'course': 'Python',
#  'city': 'banglore',
#  'marks': 92}

# %%
#add email

student["email"] = "rahul@gmail.com"

# %%
student
# Out:
# {'name': 'Rahul',
#  'age': 22,
#  'course': 'Python',
#  'city': 'banglore',
#  'marks': 92,
#  'email': 'rahul@gmail.com'}

# %%
#add phone number

student["phone"] = 9888812337

# %%
student
# Out:
# {'name': 'Rahul',
#  'age': 22,
#  'course': 'Python',
#  'city': 'banglore',
#  'marks': 92,
#  'email': 'rahul@gmail.com',
#  'phone': 9888812337}

# %%
# Remove city

student.pop("city")
# Out:
# 'banglore'

# %%
student
# Out:
# {'name': 'Rahul',
#  'age': 22,
#  'course': 'Python',
#  'marks': 92,
#  'email': 'rahul@gmail.com',
#  'phone': 9888812337}

# %%
# Retrive Name using get method

student.get("name")
# Out:
# 'Rahul'

# %%
student["name"]
# Out:
# 'Rahul'

# %%
#add or change multile things

student.update( {"email":"rahul.new@gmail.com", "phone":888889990})

# %%
student
# Out:
# {'name': 'Rahul',
#  'age': 22,
#  'course': 'Python',
#  'marks': 92,
#  'email': 'rahul.new@yahoomail.com',
#  'phone': 111111}

# %%
#create a copy


student_copy = student.copy()

# %%
print(student_copy)
# Out:
# {'name': 'Rahul', 'age': 22, 'course': 'Python', 'marks': 92, 'email': 'rahul.new@yahoomail.com', 'phone': 111111}
