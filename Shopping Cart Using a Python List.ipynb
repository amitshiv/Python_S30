# %%
cart = ["Laptop", "Keyboard","Monitor","Headphone"]

# %%
print(cart)
# Out:
# ['Laptop', 'Keyboard', 'Monitor', 'Headphone']

# %%
cart[0]
# Out:
# 'Laptop'

# %%
cart[-1]
# Out:
# 'Headphone'

# %%
cart.append("Webcam")

# %%
cart
# Out:
# ['Laptop', 'Keyboard', 'Monitor', 'Headphone', 'Webcam']

# %%
cart.insert(1,"Usb Hub")

# %%
cart
# Out:
# ['Laptop', 'Usb Hub', 'Keyboard', 'Monitor', 'Headphone', 'Webcam']

# %%
cart.remove("Keyboard")

# %%
cart
# Out:
# ['Laptop', 'Usb Hub', 'Monitor', 'Headphone', 'Webcam']

# %%
cart.pop()
# Out:
# 'Webcam'

# %%
cart
# Out:
# ['Laptop', 'Usb Hub', 'Monitor', 'Headphone']

# %%
cart.index("Monitor")
# Out:
# 2

# %%
cart.count("Laptop")
# Out:
# 1

# %%
crat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 crat
#
# NameError: name 'crat' is not defined

# %%
cart
# Out:
# ['Laptop', 'Usb Hub', 'Monitor', 'Headphone']

# %%
cart_2 = cart.copy()

# %%
cart_3 = cart

# %%
cart_2
# Out:
# ['Laptop', 'Usb Hub', 'Monitor', 'Headphone']

# %%
cart.pop()
# Out:
# 'Headphone'

# %%
cart
# Out:
# ['Laptop', 'Usb Hub', 'Monitor']

# %%
cart_2
# Out:
# ['Laptop', 'Usb Hub', 'Monitor', 'Headphone']

# %%
cart_3
# Out:
# ['Laptop', 'Usb Hub', 'Monitor']

# %%
#reverse

# %%
cart
# Out:
# ['Laptop', 'Usb Hub', 'Monitor']

# %%
cart.reverse()

# %%
cart
# Out:
# ['Monitor', 'Usb Hub', 'Laptop']

# %%
cart.sort()

# %%
cart
# Out:
# ['Laptop', 'Monitor', 'Usb Hub']

# %%
cart.clear()

# %%
cart
# Out:
# []
