# %%
product = [
    {"name":"Laptop","price":70000, "brand":"Dell "},
    {"name":"phone","price":40000, "brand":"Samsung"},
    {"name":"table","price":30000, "brand":"Apple"}
]

# %%
print(product)
# Out:
# [{'name': 'Laptop', 'price': 70000, 'brand': 'Dell '}, {'name': 'phone', 'price': 40000, 'brand': 'Samsung'}, {'name': 'table', 'price': 30000, 'brand': 'Apple'}]

# %%
type(product)
# Out:
# list

# %%
#print first product
print(product[0])
# Out:
# {'name': 'Laptop', 'price': 70000, 'brand': 'Dell '}

# %%
#print second product

print(product[1])
# Out:
# {'name': 'phone', 'price': 40000, 'brand': 'Samsung'}

# %%
print(product[2])
# Out:
# {'name': 'table', 'price': 30000, 'brand': 'Apple'}

# %%
print(product)
# Out:
# [{'name': 'Laptop', 'price': 70000, 'brand': 'Dell '}, {'name': 'phone', 'price': 40000, 'brand': 'Samsung'}, {'name': 'table', 'price': 30000, 'brand': 'Apple'}]

# %%
#change price of product

product[0]["price"] = 75000

# %%
print(product)
# Out:
# [{'name': 'Laptop', 'price': 75000, 'brand': 'Dell '}, {'name': 'phone', 'price': 40000, 'brand': 'Samsung'}, {'name': 'table', 'price': 30000, 'brand': 'Apple'}]

# %%
#add rating to the second product

product[1]["rating"] = 4.5

# %%
print(product)
# Out:
# [{'name': 'Laptop', 'price': 75000, 'brand': 'Dell '}, {'name': 'phone', 'price': 40000, 'brand': 'Samsung', 'rating': 4.5}, {'name': 'table', 'price': 30000, 'brand': 'Apple'}]

# %%
#adding new product using append

product.append(
    {"name":"smartphone", "price":15000, "brand":"Apple"

    }
)

# %%
print(product)
# Out:
# [{'name': 'Laptop', 'price': 75000, 'brand': 'Dell '}, {'name': 'phone', 'price': 40000, 'brand': 'Samsung', 'rating': 4.5}, {'name': 'table', 'price': 30000, 'brand': 'Apple'}, {'name': 'smartphone', 'price': 15000, 'brand': 'Apple'}]
