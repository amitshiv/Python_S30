# %%
laptop = {
    "brand":"Dell",
    "model":"XPS15",
    "price":120000,
    "ram":"16gb",
    "storage":"512GB SSD",
    "availabel": True
}

# %%
print(laptop)
# Out:
# {'brand': 'Dell', 'model': 'XPS15', 'price': 120000, 'ram': '16gb', 'storage': '512GB SSD', 'availabel': True}

# %%
print(laptop["brand"])
# Out:
# Dell

# %%
print(laptop["model"])
# Out:
# XPS15

# %%
print(laptop["price"])
# Out:
# 120000

# %%
print(laptop["ram"])
# Out:
# 16gb

# %%
laptop["price"] = 110000

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS15',
#  'price': 110000,
#  'ram': '16gb',
#  'storage': '512GB SSD',
#  'availabel': True}

# %%
laptop["processor"] ="Intel core i7"

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS15',
#  'price': 110000,
#  'ram': '16gb',
#  'storage': '512GB SSD',
#  'availabel': True,
#  'processor': 'Intel core i7'}

# %%
laptop["gpu"] = "NVIDIA RTX 4050"

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS15',
#  'price': 110000,
#  'ram': '16gb',
#  'storage': '512GB SSD',
#  'availabel': True,
#  'processor': 'Intel core i7',
#  'gpu': 'NVIDIA RTX 4050'}

# %%
laptop["ram"] = "32 GB"

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS15',
#  'price': 110000,
#  'ram': '32 GB',
#  'storage': '512GB SSD',
#  'availabel': True,
#  'processor': 'Intel core i7',
#  'gpu': 'NVIDIA RTX 4050'}

# %%
#delete
del laptop["availabel"]

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS15',
#  'price': 110000,
#  'ram': '32 GB',
#  'storage': '512GB SSD',
#  'processor': 'Intel core i7',
#  'gpu': 'NVIDIA RTX 4050'}

# %%
#diplay only keys

laptop.keys()
# Out:
# dict_keys(['brand', 'model', 'price', 'ram', 'storage', 'processor', 'gpu'])

# %%
#display only values

laptop.values()
# Out:
# dict_values(['Dell', 'XPS15', 110000, '32 GB', '512GB SSD', 'Intel core i7', 'NVIDIA RTX 4050'])

# %%
#keys and values display together

laptop.items()
# Out:
# dict_items([('brand', 'Dell'), ('model', 'XPS15'), ('price', 110000), ('ram', '32 GB'), ('storage', '512GB SSD'), ('processor', 'Intel core i7'), ('gpu', 'NVIDIA RTX 4050')])

# %%
mobile = {
    "brand":"Apple",
    "model":"iphone 17",
    "price":79900,
    "ram":"8GB",
    "storage":"256GB",
    "available":True
}

# %%
mobile
# Out:
# {'brand': 'Apple',
#  'model': 'iphone 17',
#  'price': 79900,
#  'ram': '8GB',
#  'storage': '256GB',
#  'available': True}
