# %%
students = [["Rahul",21,"Python"],
            ["Priya",22,"Data Sience"],
            ["Aman",20,"Machine Learning"]
            ]

# %%
print(students)
# Out:
# [['Rahul', 21, 'Python'], ['Priya', 22, 'Data Sience'], ['Aman', 20, 'Machine Learning']]

# %%
students[0]
# Out:
# ['Rahul', 21, 'Python']

# %%
students[2]
# Out:
# ['Aman', 20, 'Machine Learning']

# %%
students[0][0]
# Out:
# 'Rahul'

# %%
students[1][1]
# Out:
# 22

# %%
students
# Out:
# [['Rahul', 21, 'Python'],
#  ['Priya', 22, 'Data Sience'],
#  ['Aman', 20, 'Machine Learning']]

# %%
students[2][2]
# Out:
# 'Machine Learning'

# %%
students[1]
# Out:
# ['Priya', 22, 'Data Sience']

# %%
students[0][2] = "AI"

# %%
students
# Out:
# [['Rahul', 21, 'AI'],
#  ['Priya', 22, 'Data Sience'],
#  ['Aman', 20, 'Machine Learning']]

# %%
students.append(["Neha",23,"Python"])

# %%
students
# Out:
# [['Rahul', 21, 'AI'],
#  ['Priya', 22, 'Data Sience'],
#  ['Aman', 20, 'Machine Learning'],
#  ['Neha', 23, 'Python']]
